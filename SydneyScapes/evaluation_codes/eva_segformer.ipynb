# %%
pip install ptflops codecarbon
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting ptflops
#   Downloading ptflops-0.7.5-py3-none-any.whl (19 kB)
# Collecting codecarbon
#   Downloading codecarbon-3.2.5-py3-none-any.whl (373 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 373.1/373.1 KB 6.9 MB/s eta 0:00:0000:01
# Requirement already satisfied: torch>=2.0 in /home/21790159/.local/lib/python3.10/site-packages (from ptflops) (2.9.1)
# Collecting psutil>=6.0.0
#   Downloading psutil-7.2.2-cp36-abi3-manylinux2010_x86_64.manylinux_2_12_x86_64.manylinux_2_28_x86_64.whl (155 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.6/155.6 KB 7.9 MB/s eta 0:00:00
# Requirement already satisfied: click in /home/21790159/.local/lib/python3.10/site-packages (from codecarbon) (8.3.1)
# Requirement already satisfied: arrow in /usr/local/lib/python3.10/dist-packages (from codecarbon) (1.3.0)
# Collecting authlib>=1.2.1
#   Downloading authlib-1.6.9-py2.py3-none-any.whl (244 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 KB 14.2 MB/s eta 0:00:00
# Collecting rapidfuzz
#   Downloading rapidfuzz-3.14.3-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (3.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 27.6 MB/s eta 0:00:0000:0100:01
# Collecting pydantic
#   Downloading pydantic-2.12.5-py3-none-any.whl (463 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 463.6/463.6 KB 19.9 MB/s eta 0:00:00
# Collecting questionary
#   Downloading questionary-2.1.1-py3-none-any.whl (36 kB)
# Requirement already satisfied: rich in /home/21790159/.local/lib/python3.10/site-packages (from codecarbon) (14.3.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from codecarbon) (2.2.0)
# Collecting pycountry
#   Downloading pycountry-26.2.16-py3-none-any.whl (8.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 42.9 MB/s eta 0:00:00:00:0100:01
# Requirement already satisfied: requests in /home/21790159/.local/lib/python3.10/site-packages (from codecarbon) (2.32.5)
# Requirement already satisfied: typer in /home/21790159/.local/lib/python3.10/site-packages (from codecarbon) (0.24.1)
# Collecting nvidia-ml-py
#   Downloading nvidia_ml_py-13.595.45-py3-none-any.whl (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 KB 3.0 MB/s eta 0:00:00
# Collecting py-cpuinfo
#   Downloading py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: prometheus_client in /usr/local/lib/python3.10/dist-packages (from codecarbon) (0.19.0)
# Requirement already satisfied: cryptography in /usr/lib/python3/dist-packages (from authlib>=1.2.1->codecarbon) (3.4.8)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=2.0->ptflops) (3.13.1)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/21790159/.local/lib/python3.10/site-packages (from torch>=2.0->ptflops) (11.7.3.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/21790159/.local/lib/python3.10/site-packages (from torch>=2.0->ptflops) (12.8.93)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/21790159/.local/lib/python3.10/site-packages (from torch>=2.0->ptflops) (2.27.5)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/21790159/.local/lib/python3.10/site-packages (from torch>=2.0->ptflops) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/21790159/.local/lib/python3.10/site-packages (from torch>=2.0->ptflops) (10.3.9.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/21790159/.local/lib/python3.10/site-packages (from torch>=2.0->ptflops) (12.5.8.93)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/21790159/.local/lib/python3.10/site-packages (from torch>=2.0->ptflops) (11.3.3.83)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/21790159/.local/lib/python3.10/site-packages (from torch>=2.0->ptflops) (12.8.90)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/21790159/.local/lib/python3.10/site-packages (from torch>=2.0->ptflops) (12.8.93)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/21790159/.local/lib/python3.10/site-packages (from torch>=2.0->ptflops) (9.10.2.21)
# Requirement already satisfied: fsspec>=0.8.5 in /home/21790159/.local/lib/python3.10/site-packages (from torch>=2.0->ptflops) (2025.12.0)
# Requirement already satisfied: triton==3.5.1 in /home/21790159/.local/lib/python3.10/site-packages (from torch>=2.0->ptflops) (3.5.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/21790159/.local/lib/python3.10/site-packages (from torch>=2.0->ptflops) (12.8.90)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0->ptflops) (3.1.3)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/21790159/.local/lib/python3.10/site-packages (from torch>=2.0->ptflops) (1.13.1.3)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/21790159/.local/lib/python3.10/site-packages (from torch>=2.0->ptflops) (12.8.4.1)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/21790159/.local/lib/python3.10/site-packages (from torch>=2.0->ptflops) (0.7.1)
# Requirement already satisfied: sympy>=1.13.3 in /home/21790159/.local/lib/python3.10/site-packages (from torch>=2.0->ptflops) (1.14.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/21790159/.local/lib/python3.10/site-packages (from torch>=2.0->ptflops) (4.15.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/21790159/.local/lib/python3.10/site-packages (from torch>=2.0->ptflops) (3.4.2)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /home/21790159/.local/lib/python3.10/site-packages (from torch>=2.0->ptflops) (3.3.20)
# Requirement already satisfied: python-dateutil>=2.7.0 in /usr/local/lib/python3.10/dist-packages (from arrow->codecarbon) (2.8.2)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /usr/local/lib/python3.10/dist-packages (from arrow->codecarbon) (2.8.19.20240106)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas->codecarbon) (1.26.3)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->codecarbon) (2023.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas->codecarbon) (2022.1)
# Collecting annotated-types>=0.6.0
#   Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Collecting pydantic-core==2.41.5
#   Downloading pydantic_core-2.41.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 38.1 MB/s eta 0:00:00:00:01
# Collecting typing-inspection>=0.4.2
#   Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Requirement already satisfied: prompt_toolkit<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from questionary->codecarbon) (3.0.43)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests->codecarbon) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests->codecarbon) (1.26.5)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests->codecarbon) (2020.6.20)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->codecarbon) (3.3.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/21790159/.local/lib/python3.10/site-packages (from rich->codecarbon) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/21790159/.local/lib/python3.10/site-packages (from rich->codecarbon) (2.19.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in /home/21790159/.local/lib/python3.10/site-packages (from typer->codecarbon) (0.0.4)
# Requirement already satisfied: shellingham>=1.3.0 in /home/21790159/.local/lib/python3.10/site-packages (from typer->codecarbon) (1.5.4)
# Requirement already satisfied: mdurl~=0.1 in /home/21790159/.local/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->codecarbon) (0.1.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt_toolkit<4.0,>=2.0->questionary->codecarbon) (0.2.13)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7.0->arrow->codecarbon) (1.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/21790159/.local/lib/python3.10/site-packages (from sympy>=1.13.3->torch>=2.0->ptflops) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=2.0->ptflops) (2.1.5)
# Installing collected packages: py-cpuinfo, nvidia-ml-py, typing-inspection, rapidfuzz, pydantic-core, pycountry, psutil, authlib, annotated-types, questionary, pydantic, ptflops, codecarbon
# Successfully installed annotated-types-0.7.0 authlib-1.6.9 codecarbon-3.2.5 nvidia-ml-py-13.595.45 psutil-7.2.2 ptflops-0.7.5 py-cpuinfo-9.0.0 pycountry-26.2.16 pydantic-2.12.5 pydantic-core-2.41.5 questionary-2.1.1 rapidfuzz-3.14.3 typing-inspection-0.4.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import torch
import numpy as np
from PIL import Image
from tqdm import tqdm
from transformers import SegformerImageProcessor, SegformerForSemanticSegmentation
import evaluate
import time
from datetime import datetime
from ptflops import get_model_complexity_info
from codecarbon import EmissionsTracker

# --- Configuration ---
MODEL_ID = "nvidia/segformer-b0-finetuned-cityscapes-1024-1024" # Try B5 for higher accuracy
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
DATA_ROOT = "sydneyscapes"
VAL_LIST = os.path.join(DATA_ROOT, "val.txt")
IMG_DIR = os.path.join(DATA_ROOT, "leftImg8bit", "val")
GT_DIR = os.path.join(DATA_ROOT, "gtFine", "val")
OUTPUT_DIR = "evaluation_results"

# Cityscapes label names for reporting
ID2LABEL = {
    0: "road", 1: "sidewalk", 2: "building", 3: "wall", 4: "fence", 5: "pole", 
    6: "traffic light", 7: "traffic sign", 8: "vegetation", 9: "terrain", 10: "sky", 
    11: "person", 12: "rider", 13: "car", 14: "truck", 15: "bus", 16: "train", 
    17: "motorcycle", 18: "bicycle"
}

# Cityscapes color palette for visualization
PALETTE = [
    128, 64, 128, 244, 35, 232, 70, 70, 70, 102, 102, 156, 190, 153, 153, 153, 153, 153, 250, 170, 30,
    220, 220, 0, 107, 142, 35, 152, 251, 152, 70, 130, 180, 220, 20, 60, 255, 0, 0, 0, 0, 142, 0, 0, 70,
    0, 60, 100, 0, 80, 100, 0, 0, 230, 119, 11, 32
]

def evaluate_segformer():
    if not os.path.exists(OUTPUT_DIR):
        os.makedirs(OUTPUT_DIR)

    # 1. Load Model and Processor
    print(f"[*] Loading model and processor: {MODEL_ID}")
    processor = SegformerImageProcessor.from_pretrained(MODEL_ID)
    model = SegformerForSemanticSegmentation.from_pretrained(MODEL_ID).to(DEVICE)
    model.eval()

    # 2. Model Parameters and Complexity
    print("[*] Calculating model complexity (GFLOPS) and parameters...")
    total_params = sum(p.numel() for p in model.parameters())
    
    # Calculate GFLOPS (using a dummy input of 1024x1024 as per model name)
    try:
        with torch.cuda.device(DEVICE.index) if DEVICE.type == 'cuda' else torch.cpu.amp.autocast():
            macs, params = get_model_complexity_info(model, (3, 1024, 1024), as_strings=False,
                                                   print_per_layer_stat=False, verbose=False)
        gflops = macs * 2 / 1e9 # Approximation: 1 MAC = 2 FLOPs
    except Exception as e:
        print(f"[!] Could not calculate GFLOPS: {e}")
        gflops = 0.0

    # 3. Load Metric
    print("[*] Loading mean_iou metric...")
    metric = evaluate.load("mean_iou")

    # 4. Load Validation List
    if not os.path.exists(VAL_LIST):
        print(f"[!] Validation list not found: {VAL_LIST}")
        return

    with open(VAL_LIST, "r") as f:
        val_files = [line.strip() for line in f if line.strip()]

    print(f"[*] Starting evaluation on {len(val_files)} images on device: {DEVICE}")

    # Carbon Tracking
    print("[*] Initializing Carbon Emissions Tracker...")
    tracker = EmissionsTracker(output_dir=OUTPUT_DIR, log_level="error")
    tracker.start()

    inference_times = []
    first_image_resolution = None
    first_file_id = None
    first_pred_labels = None

    # Use tqdm with description and unit
    pbar = tqdm(val_files, desc="Evaluating Segformer", unit="image")
    for i, file_id in enumerate(pbar):
        # Paths
        img_path = os.path.join(IMG_DIR, f"{file_id}_leftImg8bit.png")
        gt_path = os.path.join(GT_DIR, f"{file_id}_gtFine_labelTrainIds.png")

        if not os.path.exists(img_path) or not os.path.exists(gt_path):
            continue

        # Load image and ground truth
        image = Image.open(img_path).convert("RGB")
        target = Image.open(gt_path)
        target_np = np.array(target)
        
        if first_image_resolution is None:
            first_image_resolution = image.size # (width, height)
            first_file_id = file_id

        # Inference with timing
        inputs = processor(images=image, return_tensors="pt").to(DEVICE)
        
        # Sync for timing if using CUDA
        if DEVICE.type == "cuda":
            torch.cuda.synchronize()
        
        start_time = time.perf_counter()
        with torch.no_grad():
            outputs = model(**inputs)
            logits = outputs.logits
        
        if DEVICE.type == "cuda":
            torch.cuda.synchronize()
        end_time = time.perf_counter()
        
        inference_times.append(end_time - start_time)

        # Upscale logits to match image size
        upsampled_logits = torch.nn.functional.interpolate(
            logits,
            size=image.size[::-1], # (height, width)
            mode="bilinear",
            align_corners=False,
        )
        pred_labels = upsampled_logits.argmax(dim=1).squeeze(0).cpu().numpy()

        if i == 0:
            first_pred_labels = pred_labels

        # Update metric
        metric.add_batch(predictions=pred_labels, references=target_np)

    # Stop Carbon Tracking
    print("\n[*] Finalizing results and carbon tracking...")
    emissions = tracker.stop()

    # 5. Final Results
    results = metric.compute(num_labels=19, ignore_index=255)
    
    if inference_times:
        avg_inference_time = sum(inference_times) / len(inference_times)
        fps = 1.0 / avg_inference_time
    else:
        avg_inference_time = 0
        fps = 0

    # Prepare Report
    report_path = os.path.join(OUTPUT_DIR, f"evaluation_report_{datetime.now().strftime('%Y%m%d_%H%M%S')}.txt")
    with open(report_path, "w") as f:
        f.write("="*40 + "\n")
        f.write(f"Evaluation Results for {MODEL_ID}\n")
        f.write(f"Date: {datetime.now().isoformat()}\n")
        f.write("="*40 + "\n\n")
        
        f.write(f"1. Model Info:\n")
        f.write(f"   Parameters: {total_params / 1e6:.2f} M\n")
        f.write(f"   GFLOPS (at 1024x1024): {gflops:.2f}\n\n")
        
        f.write(f"2. Performance:\n")
        if first_image_resolution:
            f.write(f"   Input Resolution: {first_image_resolution[0]}x{first_image_resolution[1]}\n")
        f.write(f"   Average Inference Time: {avg_inference_time:.4f} s\n")
        f.write(f"   FPS: {fps:.2f}\n\n")
        
        f.write(f"3. Environmental Impact:\n")
        f.write(f"   Estimated Carbon Footprint: {emissions:.6f} kg CO2\n\n")
        
        f.write(f"4. Segmentation Accuracy:\n")
        f.write(f"   Mean IoU: {results['mean_iou']:.4f}\n")
        f.write(f"   Mean Accuracy: {results['mean_accuracy']:.4f}\n")
        f.write(f"   Overall Accuracy: {results['overall_accuracy']:.4f}\n\n")
        
        f.write("Per-class IoU:\n")
        for i, iou in enumerate(results['per_category_iou']):
            label_name = ID2LABEL.get(i, f"Class {i}")
            f.write(f"  {label_name:15}: {iou:.4f}\n")

    print(f"[+] Evaluation complete. Report saved to: {report_path}")

    # 6. Save First Prediction Image
    if first_pred_labels is not None:
        # Replace slashes with underscores to avoid directory errors
        safe_file_id = first_file_id.replace("/", "_").replace("\\", "_")
        mask = Image.fromarray(first_pred_labels.astype(np.uint8))
        mask.putpalette(PALETTE)
        mask_path = os.path.join(OUTPUT_DIR, f"first_prediction_{safe_file_id}.png")
        mask.save(mask_path)
        print(f"[+] First prediction saved to: {mask_path}")

if __name__ == "__main__":
    evaluate_segformer()
# Out:
# [*] Loading model and processor: nvidia/segformer-b0-finetuned-cityscapes-1024-1024
# Loading weights:   0%|          | 0/208 [00:00<?, ?it/s]
# [*] Calculating model complexity (GFLOPS) and parameters...
# [*] Loading mean_iou metric...
# [*] Starting evaluation on 152 images on device: cuda
# [*] Initializing Carbon Emissions Tracker...
# Evaluating Segformer:   0%|          | 0/152 [00:00<?, ?image/s]/home/21790159/.local/lib/python3.10/site-packages/datasets/features/image.py:377: UserWarning: Downcasting array dtype int64 to int32 to be compatible with 'Pillow'
#   warnings.warn(f"Downcasting array dtype {dtype} to {dest_dtype} to be compatible with 'Pillow'")
# Evaluating Segformer: 100%|██████████| 152/152 [00:48<00:00,  3.14image/s]
# [*] Finalizing results and carbon tracking...
# [+] Evaluation complete. Report saved to: evaluation_results/evaluation_report_20260327_162603.txt
# [+] First prediction saved to: evaluation_results/first_prediction_NSWday_NSWday_000009_345013.png
